# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [0,1,2,3,4,5]
y = [0,1,4,9,16,25]

# %%
plt.plot(x,y)
plt.title('X Squared')
plt.xlabel('X axis')
# Out:
# Text(0.5, 0, 'X axis')

# %%
class Restaurant():

    def get_name(self, name):
